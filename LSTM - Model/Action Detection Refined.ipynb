# %% [markdown]
# # 1. Import and Install Dependencies

# %%
# !pip install tensorflow==2.4.1 tensorflow-gpu==2.4.1 opencv-python mediapipe sklearn matplotlib

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_CONTOURS, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)
        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# C:\Users\jairoNeto\PycharmProjects\hand-gesture-recognition-mediapipe\.venv\lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint

# %%
len(results.left_hand_landmarks.landmark)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 len(results.left_hand_landmarks.landmark)
#
# AttributeError: 'NoneType' object has no attribute 'landmark'

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten()

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.26488712,  0.14237809, -0.87308437, ...,  0.        ,
#         0.        ,  0.        ])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.26488712,  0.14237809, -0.87308437, ...,  0.        ,
#         0.        ,  0.        ])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['Qual', 'Seu', 'Nome','Vamos', 'Estudar'])


# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 0

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Coleta valores para treinamento

# %%
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, 
                          min_tracking_confidence=0.5) as holistic:
    
    for action in actions:
        
        # Espera até apertar ENTER antes de começar essa action
        print(f"\nPronto para coletar: {action}. Pressione ENTER para começar.")
        while True:
            ret, frame = cap.read()
            cv2.putText(frame, f"Pronto para coletar: {action}", (30, 200), 
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 3, cv2.LINE_AA)
            cv2.putText(frame, "Pressione ENTER para iniciar", (30, 250), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 255), 2, cv2.LINE_AA)
            cv2.imshow('OpenCV Feed', frame)

            key = cv2.waitKey(1) & 0xFF
            if key == 13:  # ENTER
                break
            elif key == ord('q'):  # Sair
                cap.release()
                cv2.destroyAllWindows()
                exit()
        
        # Loop por sequências
        for sequence in range(start_folder, start_folder + no_sequences):
            for frame_num in range(sequence_length):

                ret, frame = cap.read()
                image, results = mediapipe_detection(frame, holistic)
                draw_styled_landmarks(image, results)
                
                if frame_num == 0:
                    cv2.putText(image, 'STARTING COLLECTION', (120, 200), 
                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, f'Collecting frames for {action} Video Number {sequence}', 
                                (15, 12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, 
                                (0, 0, 255), 1, cv2.LINE_AA)
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(500)
                else:
                    cv2.putText(image, f'Collecting frames for {action} Video Number {sequence}', 
                                (15, 12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, 
                                (0, 0, 255), 1, cv2.LINE_AA)
                    cv2.imshow('OpenCV Feed', image)
                
                # Salva keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break

cap.release()
cv2.destroyAllWindows()
# Out:
# Pronto para coletar: Qual. Pressione ENTER para começar.
#
# Pronto para coletar: Seu. Pressione ENTER para começar.
#
# Pronto para coletar: Nome. Pressione ENTER para começar.
#
# Pronto para coletar: Vamos. Pressione ENTER para começar.
#
# Pronto para coletar: Estudar. Pressione ENTER para começar.

# %% [markdown]
# # 6. Processamento

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'Qual': 0, 'Seu': 1, 'Nome': 2, 'Vamos': 3, 'Estudar': 4}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (150, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (150,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (150, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (8, 5)

# %% [markdown]
# # 7. Modelo

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.optimizers import Adam

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(256, return_sequences=True, activation='relu'))
model.add(LSTM(128, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=100, callbacks=[tb_callback])
# Out:
# Epoch 1/100
# 5/5 [==============================] - 3s 177ms/step - loss: 1.6068 - categorical_accuracy: 0.3028
# Epoch 2/100
# 5/5 [==============================] - 0s 77ms/step - loss: 1.5994 - categorical_accuracy: 0.4155
# Epoch 3/100
# 5/5 [==============================] - 0s 99ms/step - loss: 1.5810 - categorical_accuracy: 0.5000
# Epoch 4/100
# 5/5 [==============================] - 0s 80ms/step - loss: 1.5338 - categorical_accuracy: 0.5000
# Epoch 5/100
# 5/5 [==============================] - 0s 79ms/step - loss: 1.4055 - categorical_accuracy: 0.5070
# Epoch 6/100
# 5/5 [==============================] - 0s 88ms/step - loss: 1.2009 - categorical_accuracy: 0.5282
# Epoch 7/100
# 5/5 [==============================] - 0s 82ms/step - loss: 0.9759 - categorical_accuracy: 0.6761
# Epoch 8/100
# 5/5 [==============================] - 0s 77ms/step - loss: 0.9122 - categorical_accuracy: 0.6479
# Epoch 9/100
# 5/5 [==============================] - 0s 76ms/step - loss: 0.6728 - categorical_accuracy: 0.8239
# Epoch 10/100
# 5/5 [==============================] - 0s 83ms/step - loss: 0.5515 - categorical_accuracy: 0.7746
# Epoch 11/100
# 5/5 [==============================] - 0s 83ms/step - loss: 0.4560 - categorical_accuracy: 0.8380
# Epoch 12/100
# 5/5 [==============================] - 0s 79ms/step - loss: 0.4222 - categorical_accuracy: 0.8451
# Epoch 13/100
# 5/5 [==============================] - 0s 88ms/step - loss: 0.3700 - categorical_accuracy: 0.8662
# Epoch 14/100
# 5/5 [==============================] - 0s 88ms/step - loss: 0.2763 - categorical_accuracy: 0.9014
# Epoch 15/100
# 5/5 [==============================] - 0s 86ms/step - loss: 0.3985 - categorical_accuracy: 0.8592
# Epoch 16/100
# 5/5 [==============================] - 0s 81ms/step - loss: 0.6784 - categorical_accuracy: 0.8310
# Epoch 17/100
# 5/5 [==============================] - 0s 79ms/step - loss: 0.4752 - categorical_accuracy: 0.8451
# Epoch 18/100
# 5/5 [==============================] - 1s 97ms/step - loss: 0.4396 - categorical_accuracy: 0.9014
# Epoch 19/100
# 5/5 [==============================] - 0s 89ms/step - loss: 0.2655 - categorical_accuracy: 0.9155
# Epoch 20/100
# 5/5 [==============================] - 0s 87ms/step - loss: 0.2704 - categorical_accuracy: 0.8803
# Epoch 21/100
# 5/5 [==============================] - 0s 84ms/step - loss: 0.2919 - categorical_accuracy: 0.9085
# Epoch 22/100
# 5/5 [==============================] - 1s 97ms/step - loss: 0.3967 - categorical_accuracy: 0.8732
# Epoch 23/100
# 5/5 [==============================] - 0s 88ms/step - loss: 0.4373 - categorical_accuracy: 0.8521
# Epoch 24/100
# 5/5 [==============================] - 0s 85ms/step - loss: 0.3128 - categorical_accuracy: 0.8732
# Epoch 25/100
# 5/5 [==============================] - 0s 85ms/step - loss: 0.1628 - categorical_accuracy: 0.9789
# Epoch 26/100
# 5/5 [==============================] - 0s 86ms/step - loss: 0.1516 - categorical_accuracy: 0.9437
# Epoch 27/100
# 5/5 [==============================] - 0s 84ms/step - loss: 0.1481 - categorical_accuracy: 0.9507
# Epoch 28/100
# 5/5 [==============================] - 0s 84ms/step - loss: 0.2072 - categorical_accuracy: 0.9085
# Epoch 29/100
# 5/5 [==============================] - 0s 87ms/step - loss: 0.2799 - categorical_accuracy: 0.8732
# Epoch 30/100
# 5/5 [==============================] - 0s 85ms/step - loss: 0.2066 - categorical_accuracy: 0.9225
# Epoch 31/100
# 5/5 [==============================] - 0s 79ms/step - loss: 0.2190 - categorical_accuracy: 0.9155
# Epoch 32/100
# 5/5 [==============================] - 0s 83ms/step - loss: 0.1641 - categorical_accuracy: 0.9437
# Epoch 33/100
# 5/5 [==============================] - 0s 80ms/step - loss: 0.1268 - categorical_accuracy: 0.9437
# Epoch 34/100
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0751 - categorical_accuracy: 0.9859
# Epoch 35/100
# 5/5 [==============================] - 0s 79ms/step - loss: 0.1165 - categorical_accuracy: 0.9366
# Epoch 36/100
# 5/5 [==============================] - 0s 83ms/step - loss: 0.1519 - categorical_accuracy: 0.9366
# Epoch 37/100
# 5/5 [==============================] - 0s 87ms/step - loss: 0.5717 - categorical_accuracy: 0.8239
# Epoch 38/100
# 5/5 [==============================] - 0s 98ms/step - loss: 0.7881 - categorical_accuracy: 0.6972
# Epoch 39/100
# 5/5 [==============================] - 0s 90ms/step - loss: 0.4892 - categorical_accuracy: 0.8662
# Epoch 40/100
# 5/5 [==============================] - 0s 77ms/step - loss: 0.3286 - categorical_accuracy: 0.9014
# Epoch 41/100
# 5/5 [==============================] - 0s 80ms/step - loss: 0.2693 - categorical_accuracy: 0.9085
# Epoch 42/100
# 5/5 [==============================] - 0s 87ms/step - loss: 0.2859 - categorical_accuracy: 0.8803
# Epoch 43/100
# 5/5 [==============================] - 0s 78ms/step - loss: 0.1293 - categorical_accuracy: 0.9577
# Epoch 44/100
# 5/5 [==============================] - 0s 87ms/step - loss: 0.1398 - categorical_accuracy: 0.9366
# Epoch 45/100
# 5/5 [==============================] - 0s 98ms/step - loss: 0.2146 - categorical_accuracy: 0.9155
# Epoch 46/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.1806 - categorical_accuracy: 0.9507
# Epoch 47/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.0729 - categorical_accuracy: 0.9789
# Epoch 48/100
# 5/5 [==============================] - 1s 102ms/step - loss: 0.0767 - categorical_accuracy: 0.9789
# Epoch 49/100
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0470 - categorical_accuracy: 0.9859
# Epoch 50/100
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0410 - categorical_accuracy: 0.9930
# Epoch 51/100
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0374 - categorical_accuracy: 0.9930
# Epoch 52/100
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0671 - categorical_accuracy: 0.9789
# Epoch 53/100
# 5/5 [==============================] - 0s 81ms/step - loss: 0.0996 - categorical_accuracy: 0.9648
# Epoch 54/100
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0516 - categorical_accuracy: 0.9789
# Epoch 55/100
# 5/5 [==============================] - 0s 81ms/step - loss: 0.1467 - categorical_accuracy: 0.9437
# Epoch 56/100
# 5/5 [==============================] - 0s 90ms/step - loss: 0.1227 - categorical_accuracy: 0.9507
# Epoch 57/100
# 5/5 [==============================] - 0s 84ms/step - loss: 0.1065 - categorical_accuracy: 0.9718
# Epoch 58/100
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0735 - categorical_accuracy: 0.9718
# Epoch 59/100
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0709 - categorical_accuracy: 0.9789
# Epoch 60/100
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0895 - categorical_accuracy: 0.9648
# Epoch 61/100
# 5/5 [==============================] - 0s 84ms/step - loss: 0.1192 - categorical_accuracy: 0.9648
# Epoch 62/100
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0388 - categorical_accuracy: 1.0000
# Epoch 63/100
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0679 - categorical_accuracy: 0.9718
# Epoch 64/100
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0398 - categorical_accuracy: 0.9859
# Epoch 65/100
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0460 - categorical_accuracy: 0.9859
# Epoch 66/100
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0252 - categorical_accuracy: 0.9930
# Epoch 67/100
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0203 - categorical_accuracy: 0.9930
# Epoch 68/100
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0232 - categorical_accuracy: 0.9930
# Epoch 69/100
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0106 - categorical_accuracy: 1.0000
# Epoch 70/100
# 5/5 [==============================] - 0s 77ms/step - loss: 0.0051 - categorical_accuracy: 1.0000
# Epoch 71/100
# 5/5 [==============================] - 0s 84ms/step - loss: 0.0029 - categorical_accuracy: 1.0000
# Epoch 72/100
# 5/5 [==============================] - 0s 83ms/step - loss: 0.0023 - categorical_accuracy: 1.0000
# Epoch 73/100
# 5/5 [==============================] - 0s 82ms/step - loss: 0.0014 - categorical_accuracy: 1.0000
# Epoch 74/100
# 5/5 [==============================] - 0s 78ms/step - loss: 9.6331e-04 - categorical_accuracy: 1.0000
# Epoch 75/100
# 5/5 [==============================] - 0s 81ms/step - loss: 7.2740e-04 - categorical_accuracy: 1.0000
# Epoch 76/100
# 5/5 [==============================] - 0s 83ms/step - loss: 6.1268e-04 - categorical_accuracy: 1.0000
# Epoch 77/100
# 5/5 [==============================] - 0s 85ms/step - loss: 5.0854e-04 - categorical_accuracy: 1.0000
# Epoch 78/100
# 5/5 [==============================] - 1s 115ms/step - loss: 4.3732e-04 - categorical_accuracy: 1.0000
# Epoch 79/100
# 5/5 [==============================] - 0s 81ms/step - loss: 3.7571e-04 - categorical_accuracy: 1.0000
# Epoch 80/100
# 5/5 [==============================] - 0s 80ms/step - loss: 3.4435e-04 - categorical_accuracy: 1.0000
# Epoch 81/100
# 5/5 [==============================] - 0s 77ms/step - loss: 3.2330e-04 - categorical_accuracy: 1.0000
# Epoch 82/100
# 5/5 [==============================] - 0s 80ms/step - loss: 2.9833e-04 - categorical_accuracy: 1.0000
# Epoch 83/100
# 5/5 [==============================] - 0s 79ms/step - loss: 2.7631e-04 - categorical_accuracy: 1.0000
# Epoch 84/100
# 5/5 [==============================] - 0s 77ms/step - loss: 2.5056e-04 - categorical_accuracy: 1.0000
# Epoch 85/100
# 5/5 [==============================] - 0s 74ms/step - loss: 2.3491e-04 - categorical_accuracy: 1.0000
# Epoch 86/100
# 5/5 [==============================] - 0s 75ms/step - loss: 2.2537e-04 - categorical_accuracy: 1.0000
# Epoch 87/100
# 5/5 [==============================] - 0s 76ms/step - loss: 2.0725e-04 - categorical_accuracy: 1.0000
# Epoch 88/100
# 5/5 [==============================] - 0s 78ms/step - loss: 1.9377e-04 - categorical_accuracy: 1.0000
# Epoch 89/100
# 5/5 [==============================] - 0s 79ms/step - loss: 1.8066e-04 - categorical_accuracy: 1.0000
# Epoch 90/100
# 5/5 [==============================] - 0s 77ms/step - loss: 1.7437e-04 - categorical_accuracy: 1.0000
# Epoch 91/100
# 5/5 [==============================] - 0s 74ms/step - loss: 1.6401e-04 - categorical_accuracy: 1.0000
# Epoch 92/100
# 1/5 [=====>........................] - ETA: 0s - loss: 4.1843e-05 - categorical_accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 model.fit(X_train, y_train, epochs=100, callbacks=[tb_callback])
#
# File ~\PycharmProjects\hand-gesture-recognition-mediapipe\.venv\lib\site-packages\tensorflow\python\keras\engine\training.py:1183, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1176 with trace.Trace(
#    1177     'train',
#    1178     epoch_num=epoch,
#    1179     step_num=step,
#    1180     batch_size=batch_size,
#    1181     _r=1):
#    1182   callbacks.on_train_batch_begin(step)
# -> 1183   tmp_logs = self.train_function(iterator)
#    1184   if data_handler.should_sync:
#    1185     context.async_wait()
#
# File ~\PycharmProjects\hand-gesture-recognition-mediapipe\.venv\lib\site-packages\tensorflow\python\eager\def_function.py:889, in Function.__call__(self, *args, **kwds)
#     886 compiler = "xla" if self._jit_compile else "nonXla"
#     888 with OptionalXlaContext(self._jit_compile):
# --> 889   result = self._call(*args, **kwds)
#     891 new_tracing_count = self.experimental_get_tracing_count()
#     892 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\PycharmProjects\hand-gesture-recognition-mediapipe\.venv\lib\site-packages\tensorflow\python\eager\def_function.py:917, in Function._call(self, *args, **kwds)
#     914   self._lock.release()
#     915   # In this case we have created variables on the first call, so we run the
#     916   # defunned version which is guaranteed to never create variables.
# --> 917   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918 elif self._stateful_fn is not None:
#     919   # Release the lock early so that multiple threads can perform the call
#     920   # in parallel.
#     921   self._lock.release()
#
# File ~\PycharmProjects\hand-gesture-recognition-mediapipe\.venv\lib\site-packages\tensorflow\python\eager\function.py:3023, in Function.__call__(self, *args, **kwargs)
#    3020 with self._lock:
#    3021   (graph_function,
#    3022    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3023 return graph_function._call_flat(
#    3024     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\PycharmProjects\hand-gesture-recognition-mediapipe\.venv\lib\site-packages\tensorflow\python\eager\function.py:1960, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1956 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1957 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1958     and executing_eagerly):
#    1959   # No tape is watching; skip to running the function.
# -> 1960   return self._build_call_outputs(self._inference_function.call(
#    1961       ctx, args, cancellation_manager=cancellation_manager))
#    1962 forward_backward = self._select_forward_and_backward_functions(
#    1963     args,
#    1964     possible_gradient_type,
#    1965     executing_eagerly)
#    1966 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\PycharmProjects\hand-gesture-recognition-mediapipe\.venv\lib\site-packages\tensorflow\python\eager\function.py:591, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     589 with _InterpolateFunctionError(self):
#     590   if cancellation_manager is None:
# --> 591     outputs = execute.execute(
#     592         str(self.signature.name),
#     593         num_outputs=self._num_outputs,
#     594         inputs=args,
#     595         attrs=attrs,
#     596         ctx=ctx)
#     597   else:
#     598     outputs = execute.execute_with_cancellation(
#     599         str(self.signature.name),
#     600         num_outputs=self._num_outputs,
#    (...)
#     603         ctx=ctx,
#     604         cancellation_manager=cancellation_manager)
#
# File ~\PycharmProjects\hand-gesture-recognition-mediapipe\.venv\lib\site-packages\tensorflow\python\eager\execute.py:59, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57 try:
#      58   ctx.ensure_initialized()
# ---> 59   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                       inputs, attrs, num_outputs)
#      61 except core._NotOkStatusException as e:
#      62   if name is not None:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 30, 64)            442112
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 30, 128)           98816
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 30, 256)           394240
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 128)               197120
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 1,142,756
# Trainable params: 1,142,756
# Non-trainable params: 0
# _________________________________________________________________

# %%
res = model.predict(X_test)

# %%
actions[np.argmax(res[4])]
# Out:
# 'Vamos'

# %%
actions[np.argmax(y_test[4])]
# Out:
# 'Vamos'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.h5')

# %%
del model

# %%
model.load_weights('action.h5')

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
print(yhat)
# Out:
# [3, 3, 0, 3, 3, 4, 0, 4]

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[6, 0],
#         [0, 2]],
#
#        [[4, 0],
#         [0, 4]],
#
#        [[6, 0],
#         [0, 2]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 1.0

# %% [markdown]
# # 11. Test em tempo real

# %%
from scipy import stats

# %%
num_classes = 6
colors = [(int(r), int(g), int(b)) for r, g, b in np.random.randint(0, 256, (num_classes, 3))]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

plt.imshow(prob_viz(res, actions, image, colors))

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.8

cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)
# Set mediapipe model
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        if not (results.pose_landmarks or results.left_hand_landmarks or results.right_hand_landmarks):
            # Mostra só a imagem, sem previsão
            cv2.imshow('OpenCV Feed', image)
            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
            continue  # pula para o próximo frame
        print(results)

        # Draw landmarks
        draw_styled_landmarks(image, results)

        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]

        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))


        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res):
                if res[np.argmax(res)] > threshold:

                    if len(sentence) > 0:
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5:
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)

        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30),
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        # Show to screen
        image_resized = cv2.resize(image, (1280, 720))
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.18.16:5000
# Press CTRL+C to quit
